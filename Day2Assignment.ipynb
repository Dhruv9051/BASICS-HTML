# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhruv9051/BASICS-HTML/blob/master/Day2Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 
#Assignment For Day 2
 
#List and its default functions
 
List=['Maths','Python']
List.insert(2,1991)    
 #using insert function
print(List)
 
List1=['Maths','Python']
List1.append('Language') 
#using append function
print(List1)
 
List1 = [1, 2, 3] 
List2 = [2, 3, 4, 5] 
List1.extend(List2)   
#using extend function
print(List1)
 
List = [1, 2, 3, 1, 2, 1, 2, 3, 2, 1] 
print(List.count(1))
#using count function
 
List = [1, 2, 3, 1, 2, 1, 2, 3, 2, 1] 
print(List.index(2)) 
#using index function
 
List = [2.3, 4.445, 3, 5.33, 1.054, 2.5] 
List.sort()
#using sort function
print(List)
 
List = [2.3, 4.445, 3, 5.33, 1.054, 2.5] 
print(List.pop(0))
#using pop function
 
List = [2.3, 4.445, 3, 5.33, 1.054, 2.5] 
List.remove(3) 
#using remove function
print(List) 
 
List = [6, 0, 4, 1] 
List.clear()
#using clear function
print(List)
 
List1=[1,2,3,4]
List2=List1.copy()
#using copy function
print(List2)
 
List=[2,3,6,7]
List.reverse()
#using reverse function
print(List)
 
#Tuple and its default functions
 
tup=('a','b','c','d','c')
print(tup.count('c'))
#using count function
 
tup=('7','python','program')
print(tup.index('python'))
#using index function
 
tup=(1,2,3,4,5,6)
print (min(tup))
#using min function
print(max(tup))
#using max function
 
tup=(1,2,3,4,5,7,85,379,264,976)
print(len(tup))
#using len function
 
#dictionary and its default functions
 
fruit={"apple":10,"banana":20,"grapes":30}
print(fruit.keys())
#using keys function
print(fruit.values())
#using values function
 
fruit1={"apple":20,"banana":40}
fruit2={"grapes":10,"melon":30}
fruit1.update(fruit2)
#using update function
print(fruit1)
 
fruit={"apple":20,"banana":40,"orange":60}
fruit.pop("orange")
#using pop function
print(fruit)
 
fruit={"apple":10,"banana":20,"grapes":30}
fruit.clear()
#using clear function
print(fruit)
 
fruit1={"apple":20,"banana":40}
fruit2=fruit1.copy()
#using copy function
print(fruit2)
 
fruit={"apple","banana","orange"}
result=dict.fromkeys(fruit,10)
#using fromkeys function
print(result)
 
fruit={"apple":20,"banana":40,"orange":60}
print(fruit.get("apple"))
print(fruit.get("grapes"))
#using get function
 
fruit={"apple":10,"banana":20,"grapes":30}
print(fruit.items())
#using items function
 
fruit={"apple":10,"banana":20,"grapes":30}
third_value=fruit.setdefault("grapes")
#using setdefault function
print(third_value)
 
#sets and its default functions
 
 
set1={'cat','dog','fish'}
set1.remove('fish')
#using remove function
print(set1)
 
numbers={1,2,3,4}
numbers.add(5)
#using add function
print(numbers)
 
numbers={1,3,6,9}
new_numbers=numbers.copy()
#using copy function
print(new_numbers)
 
chars={'a','b','c','d'}
chars.clear()
#using clear function
print(chars)
 
num1={1,2,3,4}
num2={3,4,5,6}
print(num1.difference(num2))
#using difference function
 
num1={1,2,3,4}
num2={7,5,6}
result=num1.difference_update(num2)
#usinh difference update function
print(result)
 
numbers={1,2,3,4,5}
new_numbers=numbers.discard(6)
#using discard function
print(new_numbers)
 
A={2,4,6,8}
B={1,6,5,7}
new=B.intersection(A)
#using intersection function
print(new)
 
A={2,4,6,8}
B={1,3,5,7}
new=B.intersection_update(A)
#using intersection update function
print(new)
 
A={2,4,6,8}
B={1,3,5,7}
C=A.isdisjoint(B)
#using isdisjoint function
print(C)
 
A={2,4,6,8}
B={1,3,5,7}
C=A.issubset(B)
#using issubset function
print(C)
 
A={2,4,6,8}
B={1,3,5,7}
C=A.issuperset(B)
#using issuperset function
print(C)
 
numbers={6,2,3,4,5}
A=numbers.pop()
#using pop function
print(numbers)
 
A={1,2,3,4}
B={3,4,5,6}
C=A.symmetric_difference(B)
#using symmetric_difference function
print(C)
 
A={1,2,3,4}
B={5,6}
C=A.symmetric_difference_update(B)
#using symmetric_difference_update function
print(C)
 
A={1,2,3,4,5,6}
B={5,6,7,8,9,10}
C=A.union(B)
#using union function
print(C)
 
A={1,2,3,4}
B={5,6}
C=A.update(B)
#using update function
print(C)
 
#string and its default functions
 
string="pythOn is AmaZinG"
new=string.capitalize()
#using capitalize function
print(new)
new1=string.center(24)
#using center function
print(new1)
new2=string.casefold()
#using casefold function
print(new2)
c="is"
new3=string.count(c)
#using count function
print(new3)
result=string.endswith('amazing')
#using endswith function
print(result)
str='xyz\t12345\tabc'
result=str.expandtabs()
#using expandtabs function
print(result)
string="pythöñ"
new=string.encode()
#using encode function
print(new)
str="i love python"
new=str.find("love")
print(new)
 
#using format function
print("Hello {0},your balance is {1}".format("Adam",24532))
 
new=str.index("python")
#using index function
print(new)
name="M124onica"
print(name.isalnum())
#using isalnum function
name="dhruv"
print(name.isalpha())
#using isalpha function
print(name.isdecimal())
#using isdecimal function
print(name.isdigit())
#using isdigit function
print(name.isidentifier())
#using isidentifier function
print(name.islower())
#using islower function
print(name.isnumeric())
#using isnumeric function
print(name.isprintable())
#using isprintable function
name=" a"
print(name.isspace())
name="Python Is Good"
print(name.istitle())
#using istitle function
print(name.isupper())
#using isupper function
s1="abc"
s2="123"
print(s1.join(s2))
#using join function
 
 
 
#These were some of the functions normally used
